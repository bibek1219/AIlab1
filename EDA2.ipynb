# %%
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt

# %%
# Creating a pandas dataframe 
column_name = ['sepal length','sepal width','petal length','petal width','class']
iris_df = pd.read_csv('C:/Users/ACER/Machine Learning/Dataset/Iris dataset/Iris.csv',header = None, names = column_name)
iris_df
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris_df.shape
# Out:
# (150, 5)

# %%
# Showing the category of the data
sns.countplot(data=iris_df, x='class')
iris_df['class'].value_counts()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# Pie chart
iris_df['class'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# Histogram of the data
iris_df.hist(figsize = (10,10))
# Out:
# array([[<Axes: title={'center': 'sepal length'}>,
#         <Axes: title={'center': 'sepal width'}>],
#        [<Axes: title={'center': 'petal length'}>,
#         <Axes: title={'center': 'petal width'}>]], dtype=object)

# %%
# Distplot
sns.distplot(iris_df['sepal length'],hist=False)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_84\1804179869.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris_df['sepal length'],hist=False)
# C:\Users\ACER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='sepal length', ylabel='Density'>

# %%
# Boxplot (5 point summary)
sns.boxplot(iris_df)
# Out:
# <Axes: >

# %%
# Pairplot
sns.pairplot(iris_df,hue='class')
# Out:
# C:\Users\ACER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ACER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ACER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
#Converting categorical data into numerical value
iris_df['label']= label_encoder.fit_transform(iris_df['class'])
iris_df
# Out:
#      sepal length  sepal width  petal length  petal width           class  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      label
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...

# %%
# Dropping class column
iris_df1 = iris_df.drop(['class'], axis = 1)
iris_df1
# Out:
#      sepal length  sepal width  petal length  petal width  label
# 0             5.1          3.5           1.4          0.2      0
# 1             4.9          3.0           1.4          0.2      0
# 2             4.7          3.2           1.3          0.2      0
# 3             4.6          3.1           1.5          0.2      0
# 4             5.0          3.6           1.4          0.2      0
# ..            ...          ...           ...          ...    ...
# 145           6.7          3.0           5.2          2.3      2
# 146           6.3          2.5           5.0          1.9      2
# 147           6.5          3.0           5.2          2.0      2
# 148           6.2          3.4           5.4          2.3      2
# 149           5.9          3.0           5.1          1.8      2
#
# [150 rows x 5 columns]

# %%
# Heatmap
plt.figure(figsize =(5,5))
sns.heatmap(iris_df1.corr(), annot = True)
# Out:
# <Axes: >
